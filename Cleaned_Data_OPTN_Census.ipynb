# %%
import pandas as pd

# %%
#import the csv files
optn_csv = "output/optn_remove_agg.csv"

#create dataframe csv
df = pd.read_csv(optn_csv)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Ethnicities', 'Wait Time', 'Alabama', 'Alaska',
#        'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut',
#        'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii',
#        'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan',
#        'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object')

# %%
optn_df = df.drop('Unnamed: 0', axis=1)
optn_df.head()
# Out:
#          Age  Ethnicities              Wait Time  Alabama  Alaska  Arizona  \
# 0  0-5 Years  White alone              < 30 Days        0       1        0
# 1  0-5 Years  White alone        30 to < 90 Days        1       0        4
# 2  0-5 Years  White alone  90 Days to < 6 Months        1       0        3
# 3  0-5 Years  White alone   6 Months to < 1 Year        1       0        0
# 4  0-5 Years  White alone    1 Year to < 2 Years        0       0        0
#
#    Arkansas  California  Colorado  Connecticut  ...  South Dakota  Tennessee  \
# 0         0           6         1            0  ...             0          1
# 1         2           6         4            1  ...             0          0
# 2         0           7         1            1  ...             0          4
# 3         1           0         3            0  ...             0          1
# 4         0           8         0            0  ...             0          0
#
# ...

# %%
#There are 54 columns in this dataframe, Age is the 0 column 
#I need to get the value under the state, the column name for the state, the age, ethnicity, wait time
col_alabama = optn_df.columns[3]
alabama_df = pd.DataFrame(optn_df[['Alabama', 'Age', 'Ethnicities', 'Wait Time']])
alabama_df = alabama_df.rename(columns={'Alabama': 'People'})
alabama_df['State'] = 'Alabama'

# %%
#create a loop to get all the state dataframes
for c in range(4, 54):
    col = optn_df.columns[c]
    print(col)
    #above is Alaska
    col_l = col.lower()
    print(col_l)
    #above is lowercase name
    #dataframe name below
    df_name_string = f'{col_l}_df' 
    print(df_name_string)
    #add in the columns I want to get
    df_name = pd.DataFrame(optn_df[[col, 'Age', 'Ethnicities', 'Wait Time']])
    #rename the state to "People" column
    df_name = df_name.rename(columns={col: 'People'})
    #add in the state for every value in that column
    df_name['State'] = col
    #rename the dataframe to reflect the state
    globals()[df_name_string] = pd.DataFrame(df_name)
    df_name.head()
# Out:
# Alaska
# alaska
# alaska_df
# Arizona
# arizona
# arizona_df
# Arkansas
# arkansas
# arkansas_df
# California
# california
# california_df
# Colorado
# colorado
# colorado_df
# Connecticut
# connecticut
# connecticut_df
# Delaware
# delaware
# delaware_df
# District of Columbia
# district of columbia
# district of columbia_df
# Florida
# florida
# florida_df
# Georgia
# georgia
# georgia_df
# Hawaii
# hawaii
# hawaii_df
# Idaho
# idaho
# idaho_df
# Illinois
# illinois
# illinois_df
# Indiana
# indiana
# indiana_df
# Iowa
# iowa
# iowa_df
# Kansas
# kansas
# kansas_df
# Kentucky
# kentucky
# kentucky_df
# Louisiana
# louisiana
# louisiana_df
# Maine
# maine
# maine_df
# Maryland
# maryland
# maryland_df
# Massachusetts
# massachusetts
# massachusetts_df
# Michigan
# michigan
# michigan_df
# Minnesota
# minnesota
# minnesota_df
# Mississippi
# mississippi
# mississippi_df
# Missouri
# missouri
# missouri_df
# Montana
# montana
# montana_df
# Nebraska
# nebraska
# nebraska_df
# Nevada
# ...

# %%
# %whos DataFrame
# Out:
# Variable                  Type         Data/Info
# ------------------------------------------------
# alabama_df                DataFrame         People           Age<...>n\n[359 rows x 5 columns]
# alaska_df                 DataFrame         People           Age<...>n\n[359 rows x 5 columns]
# arizona_df                DataFrame         People           Age<...>n\n[359 rows x 5 columns]
# arkansas_df               DataFrame         People           Age<...>n\n[359 rows x 5 columns]
# california_df             DataFrame         People           Age<...>n\n[359 rows x 5 columns]
# colorado_df               DataFrame         People           Age<...>n\n[359 rows x 5 columns]
# connecticut_df            DataFrame         People           Age<...>n\n[359 rows x 5 columns]
# delaware_df               DataFrame         People           Age<...>n\n[359 rows x 5 columns]
# df                        DataFrame         Unnamed: 0          <...>\n[359 rows x 55 columns]
# ...

# %%
pennsylvania_df.head()
# Out:
#    People        Age  Ethnicities              Wait Time         State
# 0       0  0-5 Years  White alone              < 30 Days  Pennsylvania
# 1       3  0-5 Years  White alone        30 to < 90 Days  Pennsylvania
# 2       2  0-5 Years  White alone  90 Days to < 6 Months  Pennsylvania
# 3       3  0-5 Years  White alone   6 Months to < 1 Year  Pennsylvania
# 4       3  0-5 Years  White alone    1 Year to < 2 Years  Pennsylvania
