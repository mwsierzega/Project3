# %%
import pandas as pd
import sqlite3
from sqlite3 import Error
from pathlib import Path
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
import numpy as np

# %%
#import the csv files

optn_csv = "output/optn_clean.csv"
#create dataframe csv
df = pd.read_csv(optn_csv)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Ethnicities', 'Wait Time', 'Alabama', 'Alaska',
#        'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut',
#        'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii',
#        'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan',
#        'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New_Hampshire', 'New_Jersey', 'New_Mexico', 'New_York',
#        'North_Carolina', 'North_Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode_Island', 'South_Carolina', 'South_Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West_Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object')

# %%
optn_df = df.drop('Unnamed: 0', axis=1)
optn_df.columns
# Out:
# Index(['Age', 'Ethnicities', 'Wait Time', 'Alabama', 'Alaska', 'Arizona',
#        'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New_Hampshire', 'New_Jersey', 'New_Mexico', 'New_York',
#        'North_Carolina', 'North_Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode_Island', 'South_Carolina', 'South_Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West_Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object')

# %%
#There are 54 columns in this dataframe, Age is the 0 column 
#I need to get the value under the state, the column name for the state, the age, ethnicity, wait time
col_alabama = optn_df.columns[3]
alabama_df = pd.DataFrame(optn_df[['Alabama', 'Age', 'Ethnicities', 'Wait Time']])
alabama_df = alabama_df.rename(columns={'Alabama': 'People'})
alabama_df['State'] = 'Alabama'

# %%
#create a loop to get all the state dataframes
for c in range(4, 54):
    col = optn_df.columns[c]
    print(col)
    #above is Alaska
    #col_l = col.lower()
    #print(col_l)
    #above is lowercase name
    #dataframe name below
    #df_name_string = f'{col_l}_df'
    df_name_string = f'{col}_df' 
    print(df_name_string)
    #add in the columns I want to get
    df_name = pd.DataFrame(optn_df[[col, 'Age', 'Ethnicities', 'Wait Time']])
    #rename the state to "People" column
    df_name = df_name.rename(columns={col: 'People'})
    #add in the state for every value in that column
    df_name['State'] = col
    #rename the dataframe to reflect the state
    globals()[df_name_string] = pd.DataFrame(df_name)
    df_name.head()
# Out:
# Alaska
# Alaska_df
# Arizona
# Arizona_df
# Arkansas
# Arkansas_df
# California
# California_df
# Colorado
# Colorado_df
# Connecticut
# Connecticut_df
# Delaware
# Delaware_df
# District of Columbia
# District of Columbia_df
# Florida
# Florida_df
# Georgia
# Georgia_df
# Hawaii
# Hawaii_df
# Idaho
# Idaho_df
# Illinois
# Illinois_df
# Indiana
# Indiana_df
# Iowa
# Iowa_df
# Kansas
# Kansas_df
# Kentucky
# Kentucky_df
# Louisiana
# Louisiana_df
# Maine
# Maine_df
# Maryland
# Maryland_df
# Massachusetts
# Massachusetts_df
# Michigan
# Michigan_df
# Minnesota
# Minnesota_df
# Mississippi
# Mississippi_df
# Missouri
# Missouri_df
# Montana
# Montana_df
# Nebraska
# Nebraska_df
# Nevada
# Nevada_df
# New_Hampshire
# New_Hampshire_df
# New_Jersey
# New_Jersey_df
# New_Mexico
# New_Mexico_df
# New_York
# New_York_df
# North_Carolina
# North_Carolina_df
# North_Dakota
# North_Dakota_df
# Ohio
# Ohio_df
# Oklahoma
# Oklahoma_df
# Oregon
# Oregon_df
# Pennsylvania
# Pennsylvania_df
# ...

# %%
#list the dataframes. Leaving out district of columbia
# %whos DataFrame
# Out:
# Variable                  Type         Data/Info
# ------------------------------------------------
# Alaska_df                 DataFrame         People           Age<...>n\n[471 rows x 5 columns]
# Arizona_df                DataFrame         People           Age<...>n\n[471 rows x 5 columns]
# Arkansas_df               DataFrame         People           Age<...>n\n[471 rows x 5 columns]
# California_df             DataFrame        People           Age <...>n\n[471 rows x 5 columns]
# Colorado_df               DataFrame         People           Age<...>n\n[471 rows x 5 columns]
# Connecticut_df            DataFrame         People           Age<...>n\n[471 rows x 5 columns]
# Delaware_df               DataFrame         People           Age<...>n\n[471 rows x 5 columns]
# District of Columbia_df   DataFrame         People           Age<...>n\n[471 rows x 5 columns]
# Florida_df                DataFrame        People           Age <...>n\n[471 rows x 5 columns]
# ...

# %%
#check a dataframe
alabama_df.head(10)
# Out:
#    People       Age                      Ethnicities              Wait Time  \
# 0     681  All Ages                      White alone               All Time
# 1      25  All Ages                      White alone              < 30 Days
# 2      49  All Ages                      White alone        30 to < 90 Days
# 3      71  All Ages                      White alone  90 Days to < 6 Months
# 4     159  All Ages                      White alone   6 Months to < 1 Year
# 5     177  All Ages                      White alone    1 Year to < 2 Years
# 6      95  All Ages                      White alone   2 Years to < 3 Years
# 7      80  All Ages                      White alone   3 Years to < 5 Years
# 8      25  All Ages                      White alone        5 or More Years
# 9     904  All Ages  Black or African American alone               All Time
#
#      State
# 0  Alabama
# 1  Alabama
# 2  Alabama
# 3  Alabama
# 4  Alabama
# 5  Alabama
# 6  Alabama
# 7  Alabama
# 8  Alabama
# ...

# %%
california_df.to_csv('output/california.csv')

# %%
#create the database
Path('optn_census.db').touch()

# %%
#create a database connection
conn = sqlite3.connect('optn_census.db')
c = conn.cursor()

# %%
alabama_df.to_sql('alabama', conn, if_exists='replace', index=False)
alaska_df.to_sql('alaska', conn, if_exists='replace', index=False)
arizona_df.to_sql('arizona', conn, if_exists='replace', index=False)
arkansas_df.to_sql('arkansas', conn, if_exists='replace', index=False)
california_df.to_sql('california', conn, if_exists='replace', index=False)
colorado_df.to_sql('colorado', conn, if_exists='replace', index=False)
connecticut_df.to_sql('connecticut', conn, if_exists='replace', index=False)
delaware_df.to_sql('delaware', conn, if_exists='replace', index=False)
florida_df.to_sql('florida', conn, if_exists='replace', index=False)
georgia_df.to_sql('georgia', conn, if_exists='replace', index=False)
hawaii_df.to_sql('hawaii', conn, if_exists='replace', index=False)
idaho_df.to_sql('idaho', conn, if_exists='replace', index=False)
illinois_df.to_sql('illinois', conn, if_exists='replace', index=False)
indiana_df.to_sql('indiana', conn, if_exists='replace', index=False)
iowa_df.to_sql('iowa', conn, if_exists='replace', index=False)
kansas_df.to_sql('kansas', conn, if_exists='replace', index=False)
kentucky_df.to_sql('kentucky', conn, if_exists='replace', index=False)
louisiana_df.to_sql('louisiana', conn, if_exists='replace', index=False)
maine_df.to_sql('maine', conn, if_exists='replace', index=False)
maryland_df.to_sql('maryland', conn, if_exists='replace', index=False)
massachusetts_df.to_sql('massachusetts', conn, if_exists='replace', index=False)
michigan_df.to_sql('michigan', conn, if_exists='replace', index=False)
minnesota_df.to_sql('minnesota', conn, if_exists='replace', index=False)
mississippi_df.to_sql('mississippi', conn, if_exists='replace', index=False)
missouri_df.to_sql('missouri', conn, if_exists='replace', index=False)
montana_df.to_sql('montana', conn, if_exists='replace', index=False)
nebraska_df.to_sql('nebraska', conn, if_exists='replace', index=False)
nevada_df.to_sql('nevada', conn, if_exists='replace', index=False)
new_hampshire_df.to_sql('new_hampshire', conn, if_exists='replace', index=False)
new_jersey_df.to_sql('new_jersey', conn, if_exists='replace', index=False)
new_mexico_df.to_sql('new_mexico', conn, if_exists='replace', index=False)
new_york_df.to_sql('new_york', conn, if_exists='replace', index=False)
north_carolina_df.to_sql('north_carolina', conn, if_exists='replace', index=False)
north_dakota_df.to_sql('north_dakota', conn, if_exists='replace', index=False)
ohio_df.to_sql('ohio', conn, if_exists='replace', index=False)
oklahoma_df.to_sql('oklahoma', conn, if_exists='replace', index=False)
oregon_df.to_sql('oregon', conn, if_exists='replace', index=False)
pennsylvania_df.to_sql('pennsylvania', conn, if_exists='replace', index=False)
rhode_island_df.to_sql('rhode_island', conn, if_exists='replace', index=False)
south_carolina_df.to_sql('south_carolina', conn, if_exists='replace', index=False)
south_dakota_df.to_sql('south_dakota', conn, if_exists='replace', index=False)
tennessee_df.to_sql('tennessee', conn, if_exists='replace', index=False)
texas_df.to_sql('texas', conn, if_exists='replace', index=False)
utah_df.to_sql('utah', conn, if_exists='replace', index=False)
vermont_df.to_sql('vermont', conn, if_exists='replace', index=False)
virginia_df.to_sql('virginia', conn, if_exists='replace', index=False)
washington_df.to_sql('washington', conn, if_exists='replace', index=False)
west_virginia_df.to_sql('west_virginia', conn, if_exists='replace', index=False)
wisconsin_df.to_sql('wisconsin', conn, if_exists='replace', index=False)
wyoming_df.to_sql('wyoming', conn, if_exists='replace', index=False)
# Out:
# /Users/kathleen/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py:2882: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
data = c.execute("SELECT * FROM pennsylvania")

for record in data:
    print(record)
# Out:
# ('2,772', 'All Ages', 'White alone', 'All Time', 'Pennsylvania')
# ('109', 'All Ages', 'White alone', '< 30 Days', 'Pennsylvania')
# ('254', 'All Ages', 'White alone', '30 to < 90 Days', 'Pennsylvania')
# ('270', 'All Ages', 'White alone', '90 Days to < 6 Months', 'Pennsylvania')
# ('491', 'All Ages', 'White alone', '6 Months to < 1 Year', 'Pennsylvania')
# ('598', 'All Ages', 'White alone', '1 Year to < 2 Years', 'Pennsylvania')
# ('349', 'All Ages', 'White alone', '2 Years to < 3 Years', 'Pennsylvania')
# ('430', 'All Ages', 'White alone', '3 Years to < 5 Years', 'Pennsylvania')
# ('271', 'All Ages', 'White alone', '5 or More Years', 'Pennsylvania')
# ('1,844', 'All Ages', 'Black or African American alone', 'All Time', 'Pennsylvania')
# ('55', 'All Ages', 'Black or African American alone', '< 30 Days', 'Pennsylvania')
# ('109', 'All Ages', 'Black or African American alone', '30 to < 90 Days', 'Pennsylvania')
# ...

# %%
census_age = pd.read_csv('output/census_age_final.csv')
census_ethn = pd.read_csv('output/census_eth_df_drop.csv')
age_ethnicity_state = pd.read_csv('output/all_waittimes.csv')
age_waittime_state = pd.read_csv('output/all_ethnicities.csv')

# %%
age_waittime_state
# Out:
#     Index           Age      Ethnicities              Wait Time  \
# 0       0      All Ages  All Ethnicities               All Time
# 1       1      All Ages  All Ethnicities              < 30 Days
# 2       2      All Ages  All Ethnicities        30 to < 90 Days
# 3       3      All Ages  All Ethnicities  90 Days to < 6 Months
# 4       4      All Ages  All Ethnicities   6 Months to < 1 Year
# ..    ...           ...              ...                    ...
# 67    475  65 and Older  All Ethnicities   6 Months to < 1 Year
# 68    476  65 and Older  All Ethnicities    1 Year to < 2 Years
# 69    477  65 and Older  All Ethnicities   2 Years to < 3 Years
# 70    478  65 and Older  All Ethnicities   3 Years to < 5 Years
# 71    479  65 and Older  All Ethnicities        5 or More Years
#
#    All Patient States Alabama  Alaska Arizona  Arkansas California  ...  \
# 0             114,059   1,638     142   1,156       485     21,066  ...
# ...

# %%
#census_age = census_age.drop('Unnamed: 0', axis=1)
#census_ethn = census_ethn.drop('Unnamed: 0', axis=1)

# %%
census_ethn.to_sql('census_ethnicities', conn, if_exists='append', index = True)
census_age.to_sql('census_ages', conn, if_exists='append', index = False)
age_ethnicity_state.to_sql('age_thnicity_state', conn, if_exists='append', index = False)
age_waittime_state.to_sql('age_waittime_state', conn, if_exists='append', index = False)

# %%
data = c.execute("SELECT * FROM census_ethnicities")
#SELECT rowid, * FROM tbl1 WHERE letter = 'B'
for record in data:
    print(record)
# Out:
# (0, 'Total:', '331,449,281', '5,024,279', '733,391', '7,151,502', '3,011,524', '39,538,223', '5,773,714', '3,605,944', '989,948', '689,545', '21,538,187', '10,711,908', '1,455,271', '1,839,106', '12,812,508', '6,785,528', '3,190,369', '2,937,880', '4,505,836', '4,657,757', '1,362,359', '6,177,224', '7,029,917', '10,077,331', '5,706,494', '2,961,279', '6,154,913', '1,084,225', '1,961,504', '3,104,614', '1,377,529', '9,288,994', '2,117,522', '20,201,249', '10,439,388', '779,094', '11,799,448', '3,959,353', '4,237,256', '13,002,700', '1,097,379', '5,118,425', '886,667', '6,910,840', '29,145,505', '3,271,616', '643,077', '8,631,393', '7,705,281', '1,793,716', '5,893,718', '3,285,874')
# ...

# %%
census_eth_df_percent = pd.read_csv('output/census_eth_df_percent.csv')
census_age_percent = pd.read_csv('output/census_age_percent.csv')

# %%
census_eth_df_percent.to_sql('census_eth_df_percent', conn, if_exists='append', index = False)
census_age_percent.to_sql('census_age_percent', conn, if_exists='append', index = False)

# %%
data_census = c.execute("SELECT * FROM census_age_percent")

for record in data_census:
    print(record)
# Out:
# (1, '0-5 years', 5.8, 6.03, 6.22, 5.4, 6.18, 5.39, 5.61, 4.74, 5.07, 5.54, 4.95, 5.83, 4.42, 6.93, 5.83, 6.48, 6.48, 6.52, 6.44, 6.23, 5.18, 5.52, 4.89, 5.79, 6.1, 6.17, 6.25, 5.85, 6.72, 5.0, 4.98, 5.58, 5.23, 5.69, 5.51, 7.02, 6.13, 6.08, 5.14, 5.45, 4.61, 5.58, 6.75, 6.06, 6.7, 8.07, 4.98, 5.81, 5.48, 5.84, 5.61, 4.31)
# (2, '6-10 Years', 5.26, 5.42, 5.49, 4.86, 5.62, 4.72, 5.14, 4.54, 4.62, 3.24, 4.43, 5.42, 4.57, 6.69, 5.39, 5.74, 5.84, 5.99, 5.78, 5.64, 4.69, 5.03, 4.49, 5.25, 5.47, 5.5, 5.57, 5.7, 6.07, 4.85, 4.64, 4.99, 5.18, 4.95, 5.0, 6.06, 5.47, 5.6, 4.91, 4.93, 4.21, 5.16, 6.1, 5.43, 6.17, 7.69, 4.63, 5.28, 5.07, 5.38, 5.1, 4.7)
# (3, '11-17 years', 7.95, 8.4, 8.09, 7.12, 8.72, 7.31, 7.81, 7.26, 6.8, 3.15, 6.76, 8.58, 5.03, 9.69, 7.86, 8.81, 8.68, 8.77, 8.74, 8.49, 7.32, 7.65, 7.11, 8.08, 8.22, 8.87, 8.41, 7.94, 8.99, 7.14, 7.52, 8.02, 6.82, 7.48, 7.72, 8.6, 8.25, 8.48, 7.45, 7.59, 6.52, 7.74, 8.67, 8.02, 8.92, 11.28, 7.52, 7.8, 7.44, 8.18, 8.04, 7.74)
# ...

# %%
conn.commit()
conn.close()
